# %% [markdown]
# # TASK

# %% [markdown]
# 1. Go to a website
#
# 2. Search for a respective product
#
# 3. Locate review part
#
# 4. Scrap all the data in local system

# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "iphone11"  #String concatenation

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone11'

# %%
uClient = uReq(flipkart_url)

# %%
uClient

# %%
flipkartPage = uClient.read()

# %%
flipkartPage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flipkart_html = bs(flipkartPage, "html.parser")

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})   #It will return in list format
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>PICK A CATEGORY</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/clothing-and-accessories/pr?sid=clo&amp;q=samsung&amp;otracker=categorytree" title="Clothing and Accessories">Clothing and Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/automotive-accesso
# ...

# %%
len(flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"}))
# Out:
# 45

# %%
bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})

# %%
bigboxes[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>PICK A CATEGORY</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/clothing-and-accessories/pr?sid=clo&amp;q=samsung&amp;otracker=categorytree" title="Clothing and Accessories">Clothing and Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/automotive-accessor
# ...

# %%
for i in bigboxes :
    print(i)
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>PICK A CATEGORY</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/clothing-and-accessories/pr?sid=clo&amp;q=samsung&amp;otracker=categorytree" title="Clothing and Accessories">Clothing and Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/automotive-accessor
# ...

# %%
del bigboxes[0 : 3]

# %%
box = bigboxes[0]

# %%
box
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBG43UGC3PYCBZF" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/samsung-galaxy-f22-denim-black-64-gb/p/itm6f47a19cb79ae?pid=MOBG43UGC3PYCBZF&amp;lid=LSTMOBG43UGC3PYCBZFSIRYTE&amp;marketplace=FLIPKART&amp;q=samsung&amp;store=search.flipkart.com&amp;srno=s_1_3&amp;otracker=search&amp;fm=organic&amp;iid=d9677d4e-c2a2-4eeb-8310-fb6ffbd61f3e.MOBG43UGC3PYCBZF.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=wle8pp16r40000001655113742428&amp;qH=fe546279a62683de" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="SAMSUNG Galaxy F22 (Denim Black, 64 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kqqykcw0/mobile/p/y/u/galaxy-f22-sm-e225fzkhins-samsung-original-imag4z99fagskjxd.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iD
# ...

# %%
box.div
# Out:
# <div class="_13oc-S"><div data-id="MOBG43UGC3PYCBZF" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/samsung-galaxy-f22-denim-black-64-gb/p/itm6f47a19cb79ae?pid=MOBG43UGC3PYCBZF&amp;lid=LSTMOBG43UGC3PYCBZFSIRYTE&amp;marketplace=FLIPKART&amp;q=samsung&amp;store=search.flipkart.com&amp;srno=s_1_3&amp;otracker=search&amp;fm=organic&amp;iid=d9677d4e-c2a2-4eeb-8310-fb6ffbd61f3e.MOBG43UGC3PYCBZF.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=wle8pp16r40000001655113742428&amp;qH=fe546279a62683de" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="SAMSUNG Galaxy F22 (Denim Black, 64 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kqqykcw0/mobile/p/y/u/galaxy-f22-sm-e225fzkhins-samsung-original-imag4z99fagskjxd.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" rea
# ...

# %%
box.div.div
# Out:
# <div data-id="MOBG43UGC3PYCBZF" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/samsung-galaxy-f22-denim-black-64-gb/p/itm6f47a19cb79ae?pid=MOBG43UGC3PYCBZF&amp;lid=LSTMOBG43UGC3PYCBZFSIRYTE&amp;marketplace=FLIPKART&amp;q=samsung&amp;store=search.flipkart.com&amp;srno=s_1_3&amp;otracker=search&amp;fm=organic&amp;iid=d9677d4e-c2a2-4eeb-8310-fb6ffbd61f3e.MOBG43UGC3PYCBZF.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=wle8pp16r40000001655113742428&amp;qH=fe546279a62683de" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="SAMSUNG Galaxy F22 (Denim Black, 64 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kqqykcw0/mobile/p/y/u/galaxy-f22-sm-e225fzkhins-samsung-original-imag4z99fagskjxd.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkb
# ...

# %%
box.div.div.div
# Out:
# <div class="_2kHMtA"><a class="_1fQZEK" href="/samsung-galaxy-f22-denim-black-64-gb/p/itm6f47a19cb79ae?pid=MOBG43UGC3PYCBZF&amp;lid=LSTMOBG43UGC3PYCBZFSIRYTE&amp;marketplace=FLIPKART&amp;q=samsung&amp;store=search.flipkart.com&amp;srno=s_1_3&amp;otracker=search&amp;fm=organic&amp;iid=d9677d4e-c2a2-4eeb-8310-fb6ffbd61f3e.MOBG43UGC3PYCBZF.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=wle8pp16r40000001655113742428&amp;qH=fe546279a62683de" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="SAMSUNG Galaxy F22 (Denim Black, 64 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kqqykcw0/mobile/p/y/u/galaxy-f22-sm-e225fzkhins-samsung-original-imag4z99fagskjxd.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><lab
# ...

# %%
box.div.div.div.a
# Out:
# <a class="_1fQZEK" href="/samsung-galaxy-f22-denim-black-64-gb/p/itm6f47a19cb79ae?pid=MOBG43UGC3PYCBZF&amp;lid=LSTMOBG43UGC3PYCBZFSIRYTE&amp;marketplace=FLIPKART&amp;q=samsung&amp;store=search.flipkart.com&amp;srno=s_1_3&amp;otracker=search&amp;fm=organic&amp;iid=d9677d4e-c2a2-4eeb-8310-fb6ffbd61f3e.MOBG43UGC3PYCBZF.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=wle8pp16r40000001655113742428&amp;qH=fe546279a62683de" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="SAMSUNG Galaxy F22 (Denim Black, 64 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kqqykcw0/mobile/p/y/u/galaxy-f22-sm-e225fzkhins-samsung-original-imag4z99fagskjxd.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><s
# ...

# %%
box.div.div.div.a['href']
# Out:
# '/samsung-galaxy-f22-denim-black-64-gb/p/itm6f47a19cb79ae?pid=MOBG43UGC3PYCBZF&lid=LSTMOBG43UGC3PYCBZFSIRYTE&marketplace=FLIPKART&q=samsung&store=search.flipkart.com&srno=s_1_3&otracker=search&fm=organic&iid=d9677d4e-c2a2-4eeb-8310-fb6ffbd61f3e.MOBG43UGC3PYCBZF.SEARCH&ppt=None&ppn=None&ssid=wle8pp16r40000001655113742428&qH=fe546279a62683de'

# %%
productLink = "https://www.flipkart.com" + box.div.div.div.a['href']

# %%
productLink
# Out:
# 'https://www.flipkart.com/samsung-galaxy-f22-denim-black-64-gb/p/itm6f47a19cb79ae?pid=MOBG43UGC3PYCBZF&lid=LSTMOBG43UGC3PYCBZFSIRYTE&marketplace=FLIPKART&q=samsung&store=search.flipkart.com&srno=s_1_3&otracker=search&fm=organic&iid=d9677d4e-c2a2-4eeb-8310-fb6ffbd61f3e.MOBG43UGC3PYCBZF.SEARCH&ppt=None&ppn=None&ssid=wle8pp16r40000001655113742428&qH=fe546279a62683de'

# %%
prodRes = requests.get(productLink)

# %%
prodRes
# Out:
# <Response [200]>

# %%
prodRes.encoding='utf-8'

# %%
prod_html = bs(prodRes.text, "html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})  #after inspection

# %%
commentboxes
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Value-for-money</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Nice battery backup, good camera and also a good display. For daily use phone is smooth and perfect.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202108/blobio-imr-202108_64dc57dc6d3040e795076e2580639986.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202108/blobio-imr-202108_56dc50922c7147cc9126bc829295701d.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https:
# ...

# %%
len(commentboxes)
# Out:
# 11

# %%
commentboxes[0].div.div
# Out:
# <div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Value-for-money</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Nice battery backup, good camera and also a good display. For daily use phone is smooth and perfect.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202108/blobio-imr-202108_64dc57dc6d3040e795076e2580639986.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202108/blobio-imr-202108_56dc50922c7147cc9126bc829295701d.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124
# ...

# %%
commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})   #Returning the name of the reviewer
# Out:
# [<p class="_2sc7ZR _2V5EHH">Rajib Pain</p>]

# %%
commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0]
# Out:
# <p class="_2sc7ZR _2V5EHH">Rajib Pain</p>

# %%
commentboxes[0].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
# Out:
# 'Rajib Pain'

# %%
for i in range(len(commentboxes)-1) :
    print(commentboxes[i].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text  )
# Out:
# Rajib Pain
# Kaushik Pal
# pritam kumar
# Flipkart Customer
# ANKUR VATSAL
# Aniket Kumar
# Cicily S
# Flipkart Customer
# Flipkart Customer
# Flipkart Customer

# %%
rating = commentboxes[0].div.div.div.div.text

# %%
rating
# Out:
# '4'

# %%
for i in range(len(commentboxes)-1) :
    print(commentboxes[i].div.div.div.div.text )
# Out:
# 4
# 4
# 5
# 5
# 4
# 5
# 5
# 1
# 1
# 5

# %%
for i in range(len(commentboxes)-1) :
    print(commentboxes[i].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text , ":" ,commentboxes[i].div.div.div.div.text, "Star rating")
# Out:
# Rajib Pain : 4 Star rating
# Kaushik Pal : 4 Star rating
# pritam kumar : 5 Star rating
# Flipkart Customer : 5 Star rating
# ANKUR VATSAL : 4 Star rating
# Aniket Kumar : 5 Star rating
# Cicily S : 5 Star rating
# Flipkart Customer : 1 Star rating
# Flipkart Customer : 1 Star rating
# Flipkart Customer : 5 Star rating

# %%
commentHead = commentboxes[0].div.div.div.p.text

# %%
commentHead
# Out:
# 'Value-for-money'

# %%
for i in range(len(commentboxes)-1) :
    print(commentboxes[i].div.div.div.p.text)
# Out:
# Value-for-money
# Good choice
# Highly recommended
# Wonderful
# good purchase
# Mind-blowing purchase
# Must buy!
# Very poor
# Useless product
# Simply awesome

# %%
for i in range(len(commentboxes)-1) :
    print(commentboxes[i].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text)
    print(commentboxes[i].div.div.div.div.text )
    print(commentboxes[i].div.div.div.p.text)
    print("")
# Out:
# Rajib Pain
# 4
# Value-for-money
#
# Kaushik Pal
# 4
# Good choice
#
# pritam kumar
# 5
# Highly recommended
#
# Flipkart Customer
# 5
# Wonderful
#
# ANKUR VATSAL
# 4
# good purchase
#
# Aniket Kumar
# 5
# Mind-blowing purchase
#
# Cicily S
# 5
# Must buy!
#
# Flipkart Customer
# 1
# Very poor
#
# Flipkart Customer
# 1
# Useless product
#
# Flipkart Customer
# 5
# Simply awesome

# %%
comtag = commentboxes[0].div.div.find_all('div', {'class': ''})[0].text

# %%
comtag
# Out:
# 'Nice battery backup, good camera and also a good display. For daily use phone is smooth and perfect.READ MORE'

# %%
for i in range(len(commentboxes)-1) :
    print(commentboxes[i].div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text)
    print(commentboxes[i].div.div.div.div.text )
    print(commentboxes[i].div.div.div.p.text)
    print(commentboxes[i].div.div.find_all('div', {'class': ''})[0].text)
    print("\n")
# Out:
# Rajib Pain
# 4
# Value-for-money
# Nice battery backup, good camera and also a good display. For daily use phone is smooth and perfect.READ MORE
#
#
# Kaushik Pal
# 4
# Good choice
# Good product in this price segment....looks like a premium smartphone.... performance is up to the mark ..... according to me , this device is perfect for the students who are doing the online classes.....don't expect high from camera or performance....READ MORE
#
#
# pritam kumar
# 5
# Highly recommended
# Best mobile in this price range.. best batry bacup camra quality is also good, no lag, much better quality, littile bit less in feathures if compared to readme series.. bt overall mindblowing mobile...i m much satisfied..READ MORE
#
#
# Flipkart Customer
# 5
# Wonderful
# This mobile gives me all things which i was found at this price. Camera, battery , Display and Many which gives me sacrifice at its price. So i really happy that samsung lover can afford in this price and gets best feature.READ MORE
# ...

# %% [markdown]
# ## Task

# %% [markdown]
# 1. Go to ineuron.ai website
#
# 2. List down all the courses
#
# 3. One by one scrap all the course page
#
# 4. Collect all the data segment wise
#
# 5. Store this data in mysql/mongodb
#
# 6. Deploy on Heroku, Aws, acp
#
# 7. Share the deployed link
#
# 8. Create an UI and showcase in html.
